# %%
#WHAT IS TAU p214, 2.3

P0 = tor*U_b

print(t0*P0*t0*n_a)
print("\n")
print(n_a*P0)
print("\n")
print(t0*P0*t0*n_b)
print("\n")
print(n_b*P0)
print("\n")
print(t0*P0*t0*n_b*n_a*n_b)
print("\n")
print(n_b*n_a*n_b*P0)
print("\n")
print(t0*P0*t0*n_a*n_b*n_a)
print("\n")
print(n_a*n_b*n_a*P0)
print("\n")
print(t0*P0*t0*n_a*n_b*n_a*n_b*n_a)
print("\n")
print(P0*n_a*n_b*n_a*n_b*n_a)

print("\n")
print(t0*P0*t0*n_b*n_a*n_b*n_a*n_b)
print("\n")
print(P0*n_b*n_a*n_b*n_a*n_b)

print("\n")
print(t0*P0*t0*n_a*n_b*n_a*n_b*n_a*n_b)
print("\n")
print(P0*n_a*n_b*n_a*n_b*n_a*n_b)

# resultats: aucune de ces equations est verifiée
# tau est nécessairement l'identité

# %%
#WHAT IS TAU p214, 2.3, with t1

P0 = tor*U_b

print(t1*P0*t1*n_a)
print("\n")
print(n_a*P0)
print("\n")
print(t1*P0*t1*n_b)
print("\n")
print(n_b*P0)
print("\n")
print(t1*P0*t1*n_b*n_a*n_b)
print("\n")
print(n_b*n_a*n_b*P0)
print("\n")
print(t1*P0*t1*n_a*n_b*n_a)
print("\n")
print(n_a*n_b*n_a*P0)
print("\n")
print(t1*P0*t1*n_a*n_b*n_a*n_b*n_a)
print("\n")
print(P0*n_a*n_b*n_a*n_b*n_a)

print("\n")
print(t1*P0*t1*n_b*n_a*n_b*n_a*n_b)
print("\n")
print(P0*n_b*n_a*n_b*n_a*n_b)

print("\n")
print(t1*P0*t1*n_a*n_b*n_a*n_b*n_a*n_b)
print("\n")
print(P0*n_a*n_b*n_a*n_b*n_a*n_b)

# same conclusion as with t0

# %%
#WHAT IS TAU p214, 2.3, with t2

P0 = tor*U_b

print(t2*P0*t2*n_a)
print("\n")
print(n_a*P0)
print("\n")
print(t2*P0*t2*n_b)
print("\n")
print(n_b*P0)
print("\n")
print(t2*P0*t2*n_b*n_a*n_b)
print("\n")
print(n_b*n_a*n_b*P0)
print("\n")
print(t2*P0*t2*n_a*n_b*n_a)
print("\n")
print(n_a*n_b*n_a*P0)
print("\n")
print(t2*P0*t2*n_a*n_b*n_a*n_b*n_a)
print("\n")
print(P0*n_a*n_b*n_a*n_b*n_a)

print("\n")
print(t2*P0*t2*n_b*n_a*n_b*n_a*n_b)
print("\n")
print(P0*n_b*n_a*n_b*n_a*n_b)

print("\n")
print(t2*P0*t2*n_a*n_b*n_a*n_b*n_a*n_b)
print("\n")
print(P0*n_a*n_b*n_a*n_b*n_a*n_b)
# same conclusion than with t0 and t1
